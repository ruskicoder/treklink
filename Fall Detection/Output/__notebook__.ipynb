# %%
# Cell 1
import os, shutil
src = '/kaggle/input/datasets/dangnguyenminhduy/falldetection'  # your dataset path
for item in os.listdir(src):
    s, d = os.path.join(src, item), os.path.join('/kaggle/working', item)
    shutil.copytree(s, d, dirs_exist_ok=True) if os.path.isdir(s) else shutil.copy2(s, d)
os.chdir('/kaggle/working')
# !pip install -q scikit-learn

# %%
# Cell 1d — clear old weights
import os, shutil
for f in ['netmodels/CNN_fall_detection/weights.h5',
          'netmodels/CNN_fall_detection/weights_best_val_accuracy.weights.h5']:
    if os.path.exists(f):
        os.remove(f)
        print(f"Removed {f}")
print("Clean")
# Out:
# Clean

# %%
# Cell 2
# !python train_fall_detection.py --model CNN
# Out:
# 2026-05-16 11:10:39.405355: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778929839.779684      49 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778929839.886700      49 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778929840.833568      49 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Zip the output folder
import shutil
shutil.make_archive('/kaggle/working/output', 'zip', '/kaggle/working')
print("Done — download output.zip from the file browser on the right")

# %%
from IPython.display import FileLink
FileLink(r'output.zip')
